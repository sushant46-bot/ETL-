# %%
import pandas as pd

# %%
df = pd.read_csv('buisnesss.csv')

# %%
df
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS   UNITS  \
# 0       BDCQ.SEA1AA  2011.06       80078         NaN      F  Number
# 1       BDCQ.SEA1AA  2011.09       78324         NaN      F  Number
# 2       BDCQ.SEA1AA  2011.12       85850         NaN      F  Number
# 3       BDCQ.SEA1AA  2012.03       90743         NaN      F  Number
# 4       BDCQ.SEA1AA  2012.06       81780         NaN      F  Number
# 5       BDCQ.SEA1AA  2012.09       79261         NaN      F  Number
# 6       BDCQ.SEA1AA  2012.12       87793         NaN      F  Number
# 7       BDCQ.SEA1AA  2013.03       91571         NaN      F  Number
# 8       BDCQ.SEA1AA  2013.06       81687         NaN      F  Number
# 9       BDCQ.SEA1AA  2013.09       81471         NaN      F  Number
# 10      BDCQ.SEA1AA  2013.12       93950         NaN      F  Number
# 11      BDCQ.SEA1AA  2014.03       97208         NaN      F  Number
# 12      BDCQ.SEA1AA  2014.06       85879         NaN      F  Number
# ...

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value            int64
# Suppressed          float64
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4      float64
# Series_title_5      float64
# dtype: object
