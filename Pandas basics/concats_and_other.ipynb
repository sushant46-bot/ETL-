# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# 6          107     Sarah    Jones      Finance      50             Accountant
# 7          108     Peter    Davis      Finance      50             Accountant
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 10         111     Peter      Doe           HR      40              Recruiter
# ...

# %%
dict1 = {"empid":[1,2,3],"deptno":[10,20,30]}
df1 = dict1 = {"empid":[1,2,3],"deptno":[10,20,30]}

# %%
dict2 = {"empid":[5,6,7],"deptno":[100,200,300]}
df2 = dict2 = {"empid":[5,6,7],"deptno":[111,222,333]}

# %%
df1
# Out:
#    empid  deptno
# 0      1      10
# 1      2      20
# 2      3      30

# %%
df2
# Out:
# {'empid': [5, 6, 7], 'deptno': [111, 222, 333]}

# %%
# Convert both to DataFrames
df1 = pd.DataFrame(df1)
df2 = pd.DataFrame(df2)

#axis 1 means two tables on top of other
df_ans = pd.concat([df1,df2],axis=1)

# %%
df_ans
# Out:
#    empid  deptno  empid  deptno
# 0      1      10      5     111
# 1      2      20      6     222
# 2      3      30      7     333

# %%
#axis 0 means two tables one top on other

df_ans = pd.concat([df1,df2],axis=0)

# %%
df_ans
# Out:
#    empid  deptno
# 0      1      10
# 1      2      20
# 2      3      30
# 0      5     111
# 1      6     222
# 2      7     333

# %%
#default join similar to Union
df_ans = pd.concat([df1,df2],axis=1,join="outer")

# %%
df_ans
# Out:
#    empid  deptno  empid  deptno
# 0      1      10      5     111
# 1      2      20      6     222
# 2      3      30      7     333

# %%
#default join similar to Union
df_ans = pd.concat([df1,df2],axis=1,join="inner")

# %%
df_ans
# Out:
#    empid  deptno  empid  deptno
# 0      1      10      5     111
# 1      2      20      6     222
# 2      3      30      7     333

# %%
#databse connectivity
