# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# 6          107     Sarah    Jones      Finance      50             Accountant
# 7          108     Peter    Davis      Finance      50             Accountant
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 10         111     Peter      Doe           HR      40              Recruiter
# ...

# %%
df['EmployeeID']
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# 12    113
# 13    114
# 14    115
# 15    116
# 16    117
# 17    118
# 18    119
# 19    120
# Name: EmployeeID, dtype: int64

# %%
#to fetch data same as SQl select EmployeeId , FirstName , salary from employess

df[['EmployeeID','FirstName','Salary']]
# Out:
#     EmployeeID FirstName  Salary
# 0          101   Michael   98396
# 1          102      Jane   92116
# 2          103   Michael   91359
# 3          104     Linda   50229
# 4          105   Michael   84321
# 5          106     Emily   83619
# 6          107     Sarah   86274
# 7          108     Peter   52380
# 8          109   Michael   88608
# 9          110     Karen   70811
# 10         111     Peter   90803
# 11         112    Robert   92989
# 12         113      John   62000
# 13         114     Linda   79333
# 14         115     Peter   87627
# 15         116     Emily   53196
# 16         117      John   74212
# 17         118     Peter   99157
# 18         119     David   74429
# 19         120     David   68177

# %%
#to fetch data same as SQl select EmployeeId , FirstName , salary from employess
col_list = ['EmployeeID','FirstName','Salary']
df[col_list]
# Out:
#     EmployeeID FirstName  Salary
# 0          101   Michael   98396
# 1          102      Jane   92116
# 2          103   Michael   91359
# 3          104     Linda   50229
# 4          105   Michael   84321
# 5          106     Emily   83619
# 6          107     Sarah   86274
# 7          108     Peter   52380
# 8          109   Michael   88608
# 9          110     Karen   70811
# 10         111     Peter   90803
# 11         112    Robert   92989
# 12         113      John   62000
# 13         114     Linda   79333
# 14         115     Peter   87627
# 15         116     Emily   53196
# 16         117      John   74212
# 17         118     Peter   99157
# 18         119     David   74429
# 19         120     David   68177

# %%
df = pd.read_csv("employees.csv",usecols= ["EmployeeID","FirstName","DeptNo"])

# %%
df
# Out:
#     EmployeeID FirstName  DeptNo
# 0          101   Michael      10
# 1          102      Jane      50
# 2          103   Michael      60
# 3          104     Linda      50
# 4          105   Michael      60
# 5          106     Emily      60
# 6          107     Sarah      50
# 7          108     Peter      50
# 8          109   Michael      50
# 9          110     Karen      50
# 10         111     Peter      40
# 11         112    Robert      30
# 12         113      John      30
# 13         114     Linda      20
# 14         115     Peter      10
# 15         116     Emily      30
# 16         117      John      10
# 17         118     Peter      60
# 18         119     David      20
# 19         120     David      50

# %%
#to display top records 
df.head()
# Out:
#    EmployeeID FirstName  DeptNo
# 0         101   Michael      10
# 1         102      Jane      50
# 2         103   Michael      60
# 3         104     Linda      50
# 4         105   Michael      60

# %%
#to display top 10 records 
df.head(10)
# Out:
#    EmployeeID FirstName  DeptNo
# 0         101   Michael      10
# 1         102      Jane      50
# 2         103   Michael      60
# 3         104     Linda      50
# 4         105   Michael      60
# 5         106     Emily      60
# 6         107     Sarah      50
# 7         108     Peter      50
# 8         109   Michael      50
# 9         110     Karen      50

# %%
#to display Bottom records 
df.tail()
# Out:
#     EmployeeID FirstName  DeptNo
# 15         116     Emily      30
# 16         117      John      10
# 17         118     Peter      60
# 18         119     David      20
# 19         120     David      50

# %%
#to display Bottom  10 records 
df.tail(10)
# Out:
#     EmployeeID FirstName  DeptNo
# 10         111     Peter      40
# 11         112    Robert      30
# 12         113      John      30
# 13         114     Linda      20
# 14         115     Peter      10
# 15         116     Emily      30
# 16         117      John      10
# 17         118     Peter      60
# 18         119     David      20
# 19         120     David      50

# %%
# If i need 11 th records 
df_11 = df.head(11)
df_11.tail(1)
# Out:
#     EmployeeID FirstName  DeptNo
# 10         111     Peter      40

# %%
#to get info of table or data
df.info
# Out:
# <bound method DataFrame.info of     EmployeeID FirstName  DeptNo
# 10         111     Peter      40>

# %%
#to get columns of table
df.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'DeptNo'], dtype='object')

# %%
#to get columns of table
df.dtypes
# Out:
# EmployeeID     int64
# FirstName     object
# DeptNo         int64
# dtype: object
